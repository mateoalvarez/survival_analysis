# %% [markdown]
# # Cleaning data with PySpark

# %% [markdown]
# ## Start spark context

# %%
import findspark
findspark.init()
import pyspark
from pyspark.sql import SQLContext
sc = pyspark.SparkContext()
sqlContext = SQLContext(sc)
print(sc)
print(sqlContext)
# Out:
# <pyspark.context.SparkContext object at 0x111b80198>
# <pyspark.sql.context.SQLContext object at 0x1117131d0>

# %%
from pyspark.sql import SparkSession
from pyspark.sql import types as stypes
from pyspark.sql.functions import udf
spark = SparkSession \
    .builder \
    .appName("Python Spark SQL cleaning data") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
from datetime import datetime
from datetime import date
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import scipy as scp
import pandas as pd
import random
random.seed()

# %% [markdown]
# ## Posts import

# %%
fields = [
    stypes.StructField("Id", stypes.IntegerType(), True),\
    stypes.StructField("PostTypeId", stypes.IntegerType(), True),\
    stypes.StructField("AcceptedAnswerId", stypes.IntegerType(), True),\
    stypes.StructField("ParentId", stypes.IntegerType(), True),\
    stypes.StructField("CreationDate", stypes.StringType(), True),\
    stypes.StructField("DeletionDate", stypes.StringType(), True),\
    stypes.StructField("Score", stypes.IntegerType(), True),\
    stypes.StructField("ViewCount", stypes.IntegerType(), True),\
    stypes.StructField("Body", stypes.StringType(), True),\
    stypes.StructField("OwnerUserId", stypes.IntegerType(), True),\
    stypes.StructField("OwnerDisplayName", stypes.StringType(), True),\
    stypes.StructField("LastEditorUserId", stypes.IntegerType(), True),\
    stypes.StructField("LastEditorDisplayName", stypes.StringType(), True),\
    stypes.StructField("LastEditDate", stypes.StringType(), True),\
    stypes.StructField("LastActivityDate", stypes.StringType(), True),\
    stypes.StructField("Title", stypes.StringType(), True),\
    stypes.StructField("Tags", stypes.StringType(), True),\
    stypes.StructField("AnswerCount", stypes.IntegerType(), True),\
    stypes.StructField("CommentCount", stypes.IntegerType(), True),\
    stypes.StructField("FavoriteCount", stypes.IntegerType(), True),\
    stypes.StructField("ClosedDate", stypes.StringType(), True),\
    stypes.StructField("CommunityOwnedDate", stypes.StringType(), True)
]
customSchema = stypes.StructType(fields)
posts = sqlContext.read\
.format('com.databricks.spark.csv')\
.load("file:///<file-path>/posts.csv",\
      schema=customSchema)

# %%
#posts.toPandas()

# %%
reduced_posts = posts.drop('ParentId','Score','ViewCount','Body','OwnerDisplayName',\
                         'LastEditorUserId','LastEditorDisplayName','LastEditDate','LastActivityDate','AnswerCount',\
                         'CommentCount','FavoriteCount','CommunityOwnedDate','DeletionDate')

# %%
#reduced_posts.describe().toPandas()

# %% [markdown]
# ## Questions import

# %% [markdown]
# ### UDF to transform questions columns

# %%
parse_time_udf = udf(lambda x: \
    float((datetime.strptime(x.split(".")[0], '%Y-%m-%dT%H:%M:%S') - datetime.min).total_seconds()),\
    stypes.FloatType()
)

parse_time_check_udf = udf(lambda x:\
    float((datetime.strptime(x.split(".")[0], '%Y-%m-%dT%H:%M:%S') - datetime.min).total_seconds())\
    if x is not None else None,\
    stypes.FloatType()
)

tag_counter_udf = udf(lambda x:\
    float(len([tag.split("&lt;")[1] for tag in x.split("&gt;")[0:-1]])),\
    stypes.FloatType()
)

title_length_udf = udf(lambda x:\
    float(len(x)),\
    stypes.FloatType()
)

# %%
questions = reduced_posts.filter(reduced_posts.PostTypeId == 1)\
.drop("PostTypeId")
questions = questions.\
withColumn("ParsedCreationDate", parse_time_udf(questions.CreationDate)).\
withColumn("ParsedClosedDate", parse_time_check_udf(questions.ClosedDate)).\
withColumn("TagCount", tag_counter_udf(questions.Tags)).\
withColumn("TitleLength", title_length_udf(questions.Title)).\
withColumnRenamed("OwnerUserId","PosterOwnerUserId").\
drop("CreationDate","ClosedDate", "Tags", "Title")

# %%
#questions.toPandas()

# %%
#questions.describe().toPandas()

# %%
min_time = questions.select(questions.ParsedCreationDate).rdd.min()[0]
print(min_time)
# Out:
# 63430377472.0

# %% [markdown]
# # Answers import

# %%
answers = reduced_posts.filter(reduced_posts.PostTypeId == 2)\
.drop("AcceptedAnswerId", "Title", "Tags", "ClosedDate","PostTypeId")
answers = answers.withColumn("AnsParsedCreationDate", parse_time_udf(answers.CreationDate)).drop(answers.CreationDate)

# %%
#answers.describe().toPandas()

# %%
answers.registerTempTable("answers")
questions.registerTempTable("questions")

# %%
accepted_answers = sqlContext\
.sql("SELECT * FROM answers WHERE answers.Id IN (SELECT AcceptedAnswerId FROM questions)")\

accepted_answers = accepted_answers\
.withColumnRenamed("Id", "AnswerId")\

# %%
#accepted_answers.toPandas()

# %%
max_time = accepted_answers.select(accepted_answers.AnsParsedCreationDate).rdd.max()[0]
print(max_time)
# Out:
# 63592824832.0

# %% [markdown]
# ## Users import

# %%
fields = [
    stypes.StructField("Id", stypes.IntegerType(), True),\
    stypes.StructField("Reputation", stypes.FloatType(), True),\
    stypes.StructField("CreationDate", stypes.StringType(), True),\
    stypes.StructField("DisplayName", stypes.StringType(), True),\
    stypes.StructField("LastAccessDate", stypes.StringType(), True),\
    stypes.StructField("WebsiteUrl", stypes.StringType(), True),\
    stypes.StructField("Location", stypes.StringType(), True),\
    stypes.StructField("AboutMe", stypes.StringType(), True),\
    stypes.StructField("Views", stypes.IntegerType(), True),\
    stypes.StructField("UpVotes", stypes.IntegerType(), True),\
    stypes.StructField("DownVotes", stypes.IntegerType(), True),\
    stypes.StructField("Age", stypes.FloatType(), True),\
    stypes.StructField("AccountId", stypes.IntegerType(), True),\
]
customSchema = stypes.StructType(fields)
users = sqlContext.read\
.format('com.databricks.spark.csv')\
.load("file:///<file-path>/users.csv",\
      schema=customSchema)
users.describe().toPandas()
users = users.drop("CreationDate","DisplayName","LastAccessDate","WebsiteUrl","Location","AboutMe","Views","UpVotes",\
                   "DownVotes","AccountId")
users = users.withColumnRenamed("Id","UserId").withColumnRenamed("Reputation","UserReputation")

# %%
users.describe().toPandas()
# Out:
#   summary              UserId      UserReputation                Age
# 0   count               43360               43360              12901
# 1    mean  31417.359202029522  171.96042435424354  33.28548174560112
# 2  stddev  19202.403149027137   2012.982474680336  10.22403146691696
# 3     min                  -1                 1.0               14.0
# 4     max               62923            198942.0               96.0

# %% [markdown]
# # Join for final dataframe

# %% [markdown]
# ### First join answers with users

# %%
questions_with_users = questions.join(users, questions.PosterOwnerUserId == users.UserId, "left").\
withColumnRenamed("Age","PosterAge").withColumnRenamed("UserReputation","PosterReputation").\
drop("PosterOwnerUserId","UserId")
join_df = questions_with_users.join(accepted_answers, accepted_answers.AnswerId == questions.AcceptedAnswerId, 'full')
join_df = join_df.join(users, join_df.OwnerUserId == users.UserId, "left").\
drop("AcceptedAnswerId","UserId","OwnerUserId", "AnswerId", "Id")

# %%
#join_df.toPandas()

# %%
join_df.describe().toPandas()
# Out:
#   summary     ParsedCreationDate     ParsedClosedDate            TagCount  \
# 0   count                  29301                 2511               29301
# 1    mean  6.3530990516967476E10  6.35485619340693E10  2.0557660148117813
# 2  stddev    4.504117517012715E7  3.532019377350662E7  0.9919622077292334
# 3     min           6.3430377E10         6.3431139E10                 1.0
# 4     max           6.3592829E10         6.3592829E10                 5.0
#
#          TitleLength    PosterReputation           PosterAge  \
# 0              29301               28727               12214
# 1  59.35329852223474  12918.052981515648   34.68536106107745
# 2  22.55610271635549   33500.48405203392  11.211497949946038
# 3               15.0                 1.0                14.0
# 4              168.0            198942.0                96.0
#
#   AnsParsedCreationDate     UserReputation                Age
# 0                 17917              17208               7763
# 1  6.352499363107306E10  49932.78074151558  37.24591008630684
# 2  4.6620306413311735E7  63437.14410370897  9.559868164116324
# 3          6.3430377E10                1.0               14.0
# 4          6.3592825E10           198942.0               96.0

# %% [markdown]
# ## Final formatting and adding censored variable and final time

# %%
def final_time(ParsedCreationDate, ParsedClosedDate, AnsParsedCreationDate):

    if(AnsParsedCreationDate):
        return AnsParsedCreationDate-ParsedCreationDate
    elif(ParsedClosedDate):
        return ParsedClosedDate-ParsedCreationDate
    else:
        return max_time-ParsedCreationDate

final_time_udf = udf(final_time, stypes.FloatType())

def censoring_status(ParsedCreationDate, ParsedClosedDate, AnsParsedCreationDate):
    
    if(AnsParsedCreationDate):
        return float(1)
    elif(ParsedClosedDate):
        return float(0)
    else:
        return float(0)
    
censoring_status_udf = udf(censoring_status, stypes.FloatType())

# %%
final_df = join_df.\
withColumn("FinalTime",\
final_time_udf(join_df.ParsedCreationDate, join_df.ParsedClosedDate, join_df.AnsParsedCreationDate)).\
withColumn("CensoringStatus",\
censoring_status_udf(join_df.ParsedCreationDate, join_df.ParsedClosedDate, join_df.AnsParsedCreationDate)).\
drop("ParsedCreationDate", "ParsedClosedDate", "AnsParsedCreationDate")

# %%
final_df.describe().toPandas()
# Out:
#   summary            TagCount        TitleLength    PosterReputation  \
# 0   count               29301              29301               28727
# 1    mean  2.0557660148117813  59.35329852223474  12918.052981515648
# 2  stddev  0.9919622077292334  22.55610271635549   33500.48405203392
# 3     min                 1.0               15.0                 1.0
# 4     max                 5.0              168.0            198942.0
#
#             PosterAge     UserReputation                Age  \
# 0               12214              17208               7763
# 1   34.68536106107745  49932.78074151558  37.24591008630684
# 2  11.211497949946038  63437.14410370897  9.559868164116324
# 3                14.0                1.0               14.0
# 4                96.0           198942.0               96.0
#
#               FinalTime      CensoringStatus
# 0                 29301                29301
# 1  1.7990164601617694E7   0.6114808368315074
# 2   3.325815829370682E7  0.48742192326517086
# 3          -5.6172544E7                  0.0
# 4          1.62443264E8                  1.0

# %% [markdown]
# ## Filtering invalid results

# %%
final_filtered_df = final_df.filter(final_df.FinalTime > float(0))

# %%
final_filtered_df.describe().toPandas()
# Out:
#   summary            TagCount         TitleLength    PosterReputation  \
# 0   count               24009               24009               23517
# 1    mean   2.058894581198717    59.9233204215086  12649.858017604287
# 2  stddev  0.9926152490165466  22.637822393134446   33794.18142702922
# 3     min                 1.0                15.0                 1.0
# 4     max                 5.0               168.0            198942.0
#
#             PosterAge      UserReputation                Age  \
# 0                9683               12425               5554
# 1   34.83228338324899  46809.372796780684  37.44382427079582
# 2  11.252678205914636   62553.06355062486  9.477650292365588
# 3                14.0                 1.0               14.0
# 4                96.0            198942.0               96.0
#
#              FinalTime     CensoringStatus
# 0                24009               24009
# 1  2.195890047365571E7  0.5387146486734141
# 2  3.553240806671485E7  0.4985093045706418
# 3               4096.0                 0.0
# 4         1.62443264E8                 1.0

# %% [markdown]
# ## Dealing with missing values

# %% [markdown]
# Age and UserReputation are data related to the user that posted the answer, and so there are a lot of missing values, as there are numerous not answered questions (censored data). Therefore these features are omited from the survival analysis

# %%
final_reduced_df = final_filtered_df.drop("Age","UserReputation")
final_reduced_df.describe().toPandas()
# Out:
#   summary            TagCount         TitleLength    PosterReputation  \
# 0   count               24009               24009               23517
# 1    mean   2.058894581198717    59.9233204215086  12649.858017604287
# 2  stddev  0.9926152490165466  22.637822393134446   33794.18142702922
# 3     min                 1.0                15.0                 1.0
# 4     max                 5.0               168.0            198942.0
#
#             PosterAge            FinalTime     CensoringStatus
# 0                9683                24009               24009
# 1   34.83228338324899  2.195890047365571E7  0.5387146486734141
# 2  11.252678205914636  3.553240806671485E7  0.4985093045706418
# 3                14.0               4096.0                 0.0
# 4                96.0         1.62443264E8                 1.0

# %% [markdown]
# ### UDFs to fill NaNs

# %% [markdown]
# ### Poster Reputation
# The feature PosterReputation does not follow any specific distribution, so missing data is imputed randomly.

# %%
min_reputation = final_reduced_df.select("PosterReputation").\
where(final_reduced_df.PosterReputation.isNotNull()).rdd.min()[0]
max_reputation = final_reduced_df.select("PosterReputation").\
where(final_reduced_df.PosterReputation.isNotNull()).rdd.max()[0]

# %%
final_red_pr_df = final_reduced_df.fillna(random.randint(min_reputation, max_reputation), subset=["PosterReputation"])

# %%
final_red_pr_df.describe().toPandas()
# Out:
#   summary            TagCount         TitleLength    PosterReputation  \
# 0   count               24009               24009               24009
# 1    mean   2.058894581198717    59.9233204215086  15403.269898787954
# 2  stddev  0.9926152490165466  22.637822393134446    38484.1971579612
# 3     min                 1.0                15.0                 1.0
# 4     max                 5.0               168.0            198942.0
#
#             PosterAge            FinalTime     CensoringStatus
# 0                9683                24009               24009
# 1   34.83228338324899  2.195890047365571E7  0.5387146486734141
# 2  11.252678205914636  3.553240806671485E7  0.4985093045706418
# 3                14.0               4096.0                 0.0
# 4                96.0         1.62443264E8                 1.0

# %% [markdown]
# ### Poster Age
# The feature PosterAge misses the majority of the data, having only around 40% of the total data. To fill the missing values of this feature, MICE technique has been compared with KNN method, both contained in the python package fancyimpute.

# %%
import fancyimpute

# %%
from fancyimpute import MICE, SoftImpute, KNN
solver = SoftImpute(verbose=False)
#backup the column names
column_names=final_red_pr_df.columns

# %%
final_matrix = final_red_pr_df.toPandas().as_matrix()
solver = MICE(verbose=0)
final_matrix_mice = solver.complete(final_matrix)

# %%
final_matrix_knn = KNN(k=3).complete(final_matrix)
# Out:
# Imputing row 1/24009 with 0 missing, elapsed time: 83.946
# Imputing row 101/24009 with 0 missing, elapsed time: 83.958
# Imputing row 201/24009 with 0 missing, elapsed time: 83.967
# Imputing row 301/24009 with 1 missing, elapsed time: 83.977
# Imputing row 401/24009 with 0 missing, elapsed time: 83.986
# Imputing row 501/24009 with 1 missing, elapsed time: 83.995
# Imputing row 601/24009 with 0 missing, elapsed time: 84.004
# Imputing row 701/24009 with 1 missing, elapsed time: 84.012
# Imputing row 801/24009 with 0 missing, elapsed time: 84.022
# Imputing row 901/24009 with 0 missing, elapsed time: 84.030
# Imputing row 1001/24009 with 1 missing, elapsed time: 84.039
# Imputing row 1101/24009 with 0 missing, elapsed time: 84.051
# Imputing row 1201/24009 with 1 missing, elapsed time: 84.060
# Imputing row 1301/24009 with 0 missing, elapsed time: 84.069
# Imputing row 1401/24009 with 0 missing, elapsed time: 84.081
# Imputing row 1501/24009 with 0 missing, elapsed time: 84.090
# Imputing row 1601/24009 with 1 missing, elapsed time: 84.099
# Imputing row 1701/24009 with 0 missing, elapsed time: 84.106
# Imputing row 1801/24009 with 1 missing, elapsed time: 84.116
# Imputing row 1901/24009 with 1 missing, elapsed time: 84.127
# Imputing row 2001/24009 with 0 missing, elapsed time: 84.136
# Imputing row 2101/24009 with 1 missing, elapsed time: 84.146
# Imputing row 2201/24009 with 1 missing, elapsed time: 84.158
# Imputing row 2301/24009 with 1 missing, elapsed time: 84.168
# Imputing row 2401/24009 with 1 missing, elapsed time: 84.177
# Imputing row 2501/24009 with 1 missing, elapsed time: 84.187
# Imputing row 2601/24009 with 0 missing, elapsed time: 84.197
# Imputing row 2701/24009 with 1 missing, elapsed time: 84.208
# Imputing row 2801/24009 with 0 missing, elapsed time: 84.216
# Imputing row 2901/24009 with 1 missing, elapsed time: 84.226
# Imputing row 3001/24009 with 0 missing, elapsed time: 84.238
# Imputing row 3101/24009 with 1 missing, elapsed time: 84.247
# Imputing row 3201/24009 with 1 missing, elapsed time: 84.254
# Imputing row 3301/24009 with 0 missing, elapsed time: 84.264
# Imputing row 3401/24009 with 0 missing, elapsed time: 84.274
# Imputing row 3501/24009 with 1 missing, elapsed time: 84.287
# Imputing row 3601/24009 with 1 missing, elapsed time: 84.302
# Imputing row 3701/24009 with 1 missing, elapsed time: 84.313
# Imputing row 3801/24009 with 1 missing, elapsed time: 84.332
# Imputing row 3901/24009 with 1 missing, elapsed time: 84.343
# Imputing row 4001/24009 with 1 missing, elapsed time: 84.355
# Imputing row 4101/24009 with 1 missing, elapsed time: 84.367
# Imputing row 4201/24009 with 1 missing, elapsed time: 84.382
# Imputing row 4301/24009 with 1 missing, elapsed time: 84.399
# Imputing row 4401/24009 with 1 missing, elapsed time: 84.412
# Imputing row 4501/24009 with 0 missing, elapsed time: 84.427
# Imputing row 4601/24009 with 0 missing, elapsed time: 84.443
# Imputing row 4701/24009 with 1 missing, elapsed time: 84.459
# Imputing row 4801/24009 with 1 missing, elapsed time: 84.474
# Imputing row 4901/24009 with 1 missing, elapsed time: 84.490
# Imputing row 5001/24009 with 0 missing, elapsed time: 84.505
# Imputing row 5101/24009 with 1 missing, elapsed time: 84.518
# Imputing row 5201/24009 with 1 missing, elapsed time: 84.536
# Imputing row 5301/24009 with 0 missing, elapsed time: 84.551
# Imputing row 5401/24009 with 1 missing, elapsed time: 84.567
# Imputing row 5501/24009 with 1 missing, elapsed time: 84.582
# Imputing row 5601/24009 with 1 missing, elapsed time: 84.597
# Imputing row 5701/24009 with 1 missing, elapsed time: 84.612
# Imputing row 5801/24009 with 1 missing, elapsed time: 84.626
# Imputing row 5901/24009 with 0 missing, elapsed time: 84.639
# Imputing row 6001/24009 with 0 missing, elapsed time: 84.650
# Imputing row 6101/24009 with 0 missing, elapsed time: 84.665
# Imputing row 6201/24009 with 0 missing, elapsed time: 84.679
# Imputing row 6301/24009 with 0 missing, elapsed time: 84.695
# Imputing row 6401/24009 with 1 missing, elapsed time: 84.710
# Imputing row 6501/24009 with 0 missing, elapsed time: 84.724
# Imputing row 6601/24009 with 1 missing, elapsed time: 84.740
# Imputing row 6701/24009 with 1 missing, elapsed time: 84.753
# Imputing row 6801/24009 with 1 missing, elapsed time: 84.765
# Imputing row 6901/24009 with 0 missing, elapsed time: 84.778
# Imputing row 7001/24009 with 0 missing, elapsed time: 84.793
# Imputing row 7101/24009 with 1 missing, elapsed time: 84.806
# Imputing row 7201/24009 with 1 missing, elapsed time: 84.818
# Imputing row 7301/24009 with 1 missing, elapsed time: 84.832
# Imputing row 7401/24009 with 1 missing, elapsed time: 84.847
# Imputing row 7501/24009 with 1 missing, elapsed time: 84.863
# Imputing row 7601/24009 with 1 missing, elapsed time: 84.880
# Imputing row 7701/24009 with 0 missing, elapsed time: 84.895
# Imputing row 7801/24009 with 1 missing, elapsed time: 84.908
# Imputing row 7901/24009 with 0 missing, elapsed time: 84.924
# Imputing row 8001/24009 with 1 missing, elapsed time: 84.940
# Imputing row 8101/24009 with 1 missing, elapsed time: 84.958
# Imputing row 8201/24009 with 0 missing, elapsed time: 84.973
# Imputing row 8301/24009 with 0 missing, elapsed time: 84.988
# Imputing row 8401/24009 with 1 missing, elapsed time: 85.004
# Imputing row 8501/24009 with 1 missing, elapsed time: 85.019
# Imputing row 8601/24009 with 1 missing, elapsed time: 85.033
# Imputing row 8701/24009 with 1 missing, elapsed time: 85.049
# Imputing row 8801/24009 with 1 missing, elapsed time: 85.068
# Imputing row 8901/24009 with 1 missing, elapsed time: 85.086
# Imputing row 9001/24009 with 1 missing, elapsed time: 85.099
# Imputing row 9101/24009 with 1 missing, elapsed time: 85.113
# Imputing row 9201/24009 with 1 missing, elapsed time: 85.128
# Imputing row 9301/24009 with 1 missing, elapsed time: 85.142
# Imputing row 9401/24009 with 0 missing, elapsed time: 85.158
# Imputing row 9501/24009 with 1 missing, elapsed time: 85.173
# Imputing row 9601/24009 with 1 missing, elapsed time: 85.193
# Imputing row 9701/24009 with 1 missing, elapsed time: 85.211
# Imputing row 9801/24009 with 1 missing, elapsed time: 85.226
# Imputing row 9901/24009 with 1 missing, elapsed time: 85.241
# Imputing row 10001/24009 with 0 missing, elapsed time: 85.257
# Imputing row 10101/24009 with 1 missing, elapsed time: 85.272
# Imputing row 10201/24009 with 1 missing, elapsed time: 85.286
# Imputing row 10301/24009 with 0 missing, elapsed time: 85.302
# Imputing row 10401/24009 with 1 missing, elapsed time: 85.320
# Imputing row 10501/24009 with 0 missing, elapsed time: 85.336
# Imputing row 10601/24009 with 1 missing, elapsed time: 85.350
# Imputing row 10701/24009 with 0 missing, elapsed time: 85.364
# Imputing row 10801/24009 with 1 missing, elapsed time: 85.379
# Imputing row 10901/24009 with 0 missing, elapsed time: 85.393
# Imputing row 11001/24009 with 1 missing, elapsed time: 85.408
# Imputing row 11101/24009 with 1 missing, elapsed time: 85.423
# Imputing row 11201/24009 with 1 missing, elapsed time: 85.439
# Imputing row 11301/24009 with 1 missing, elapsed time: 85.455
# Imputing row 11401/24009 with 1 missing, elapsed time: 85.468
# Imputing row 11501/24009 with 1 missing, elapsed time: 85.482
# Imputing row 11601/24009 with 0 missing, elapsed time: 85.499
# Imputing row 11701/24009 with 0 missing, elapsed time: 85.514
# Imputing row 11801/24009 with 0 missing, elapsed time: 85.530
# Imputing row 11901/24009 with 0 missing, elapsed time: 85.545
# Imputing row 12001/24009 with 1 missing, elapsed time: 85.562
# Imputing row 12101/24009 with 1 missing, elapsed time: 85.578
# Imputing row 12201/24009 with 1 missing, elapsed time: 85.593
# Imputing row 12301/24009 with 0 missing, elapsed time: 85.609
# Imputing row 12401/24009 with 0 missing, elapsed time: 85.625
# Imputing row 12501/24009 with 1 missing, elapsed time: 85.640
# Imputing row 12601/24009 with 0 missing, elapsed time: 85.654
# Imputing row 12701/24009 with 1 missing, elapsed time: 85.668
# Imputing row 12801/24009 with 0 missing, elapsed time: 85.682
# Imputing row 12901/24009 with 0 missing, elapsed time: 85.699
# Imputing row 13001/24009 with 1 missing, elapsed time: 85.716
# Imputing row 13101/24009 with 1 missing, elapsed time: 85.731
# Imputing row 13201/24009 with 1 missing, elapsed time: 85.744
# Imputing row 13301/24009 with 1 missing, elapsed time: 85.758
# Imputing row 13401/24009 with 1 missing, elapsed time: 85.774
# Imputing row 13501/24009 with 1 missing, elapsed time: 85.788
# Imputing row 13601/24009 with 0 missing, elapsed time: 85.802
# Imputing row 13701/24009 with 1 missing, elapsed time: 85.814
# Imputing row 13801/24009 with 0 missing, elapsed time: 85.828
# Imputing row 13901/24009 with 1 missing, elapsed time: 85.838
# Imputing row 14001/24009 with 1 missing, elapsed time: 85.847
# Imputing row 14101/24009 with 1 missing, elapsed time: 85.855
# Imputing row 14201/24009 with 1 missing, elapsed time: 85.863
# Imputing row 14301/24009 with 1 missing, elapsed time: 85.871
# Imputing row 14401/24009 with 0 missing, elapsed time: 85.884
# Imputing row 14501/24009 with 0 missing, elapsed time: 85.893
# Imputing row 14601/24009 with 0 missing, elapsed time: 85.903
# Imputing row 14701/24009 with 0 missing, elapsed time: 85.913
# Imputing row 14801/24009 with 0 missing, elapsed time: 85.922
# Imputing row 14901/24009 with 1 missing, elapsed time: 85.930
# Imputing row 15001/24009 with 0 missing, elapsed time: 85.938
# Imputing row 15101/24009 with 0 missing, elapsed time: 85.949
# Imputing row 15201/24009 with 0 missing, elapsed time: 85.958
# Imputing row 15301/24009 with 1 missing, elapsed time: 85.968
# Imputing row 15401/24009 with 1 missing, elapsed time: 85.976
# Imputing row 15501/24009 with 1 missing, elapsed time: 85.989
# Imputing row 15601/24009 with 1 missing, elapsed time: 85.999
# Imputing row 15701/24009 with 1 missing, elapsed time: 86.010
# Imputing row 15801/24009 with 0 missing, elapsed time: 86.019
# Imputing row 15901/24009 with 1 missing, elapsed time: 86.029
# Imputing row 16001/24009 with 1 missing, elapsed time: 86.039
# Imputing row 16101/24009 with 0 missing, elapsed time: 86.049
# Imputing row 16201/24009 with 0 missing, elapsed time: 86.060
# Imputing row 16301/24009 with 1 missing, elapsed time: 86.068
# Imputing row 16401/24009 with 1 missing, elapsed time: 86.079
# Imputing row 16501/24009 with 1 missing, elapsed time: 86.086
# Imputing row 16601/24009 with 0 missing, elapsed time: 86.096
# Imputing row 16701/24009 with 1 missing, elapsed time: 86.105
# Imputing row 16801/24009 with 0 missing, elapsed time: 86.115
# Imputing row 16901/24009 with 0 missing, elapsed time: 86.127
# Imputing row 17001/24009 with 1 missing, elapsed time: 86.137
# Imputing row 17101/24009 with 0 missing, elapsed time: 86.144
# Imputing row 17201/24009 with 1 missing, elapsed time: 86.156
# Imputing row 17301/24009 with 1 missing, elapsed time: 86.166
# Imputing row 17401/24009 with 1 missing, elapsed time: 86.177
# Imputing row 17501/24009 with 0 missing, elapsed time: 86.185
# Imputing row 17601/24009 with 1 missing, elapsed time: 86.196
# Imputing row 17701/24009 with 1 missing, elapsed time: 86.208
# Imputing row 17801/24009 with 1 missing, elapsed time: 86.217
# Imputing row 17901/24009 with 0 missing, elapsed time: 86.226
# Imputing row 18001/24009 with 0 missing, elapsed time: 86.238
# Imputing row 18101/24009 with 1 missing, elapsed time: 86.247
# Imputing row 18201/24009 with 1 missing, elapsed time: 86.256
# Imputing row 18301/24009 with 1 missing, elapsed time: 86.267
# Imputing row 18401/24009 with 1 missing, elapsed time: 86.277
# Imputing row 18501/24009 with 0 missing, elapsed time: 86.286
# Imputing row 18601/24009 with 0 missing, elapsed time: 86.296
# Imputing row 18701/24009 with 1 missing, elapsed time: 86.307
# Imputing row 18801/24009 with 0 missing, elapsed time: 86.318
# Imputing row 18901/24009 with 0 missing, elapsed time: 86.329
# Imputing row 19001/24009 with 0 missing, elapsed time: 86.340
# Imputing row 19101/24009 with 1 missing, elapsed time: 86.348
# Imputing row 19201/24009 with 1 missing, elapsed time: 86.359
# Imputing row 19301/24009 with 1 missing, elapsed time: 86.369
# Imputing row 19401/24009 with 0 missing, elapsed time: 86.380
# Imputing row 19501/24009 with 0 missing, elapsed time: 86.389
# Imputing row 19601/24009 with 1 missing, elapsed time: 86.398
# Imputing row 19701/24009 with 0 missing, elapsed time: 86.409
# Imputing row 19801/24009 with 1 missing, elapsed time: 86.419
# Imputing row 19901/24009 with 0 missing, elapsed time: 86.430
# Imputing row 20001/24009 with 1 missing, elapsed time: 86.438
# Imputing row 20101/24009 with 1 missing, elapsed time: 86.446
# Imputing row 20201/24009 with 0 missing, elapsed time: 86.456
# Imputing row 20301/24009 with 1 missing, elapsed time: 86.464
# Imputing row 20401/24009 with 0 missing, elapsed time: 86.472
# Imputing row 20501/24009 with 1 missing, elapsed time: 86.481
# Imputing row 20601/24009 with 1 missing, elapsed time: 86.491
# Imputing row 20701/24009 with 1 missing, elapsed time: 86.503
# Imputing row 20801/24009 with 0 missing, elapsed time: 86.512
# Imputing row 20901/24009 with 1 missing, elapsed time: 86.523
# Imputing row 21001/24009 with 1 missing, elapsed time: 86.531
# Imputing row 21101/24009 with 0 missing, elapsed time: 86.541
# Imputing row 21201/24009 with 1 missing, elapsed time: 86.548
# Imputing row 21301/24009 with 0 missing, elapsed time: 86.559
# Imputing row 21401/24009 with 1 missing, elapsed time: 86.567
# Imputing row 21501/24009 with 0 missing, elapsed time: 86.579
# Imputing row 21601/24009 with 0 missing, elapsed time: 86.585
# Imputing row 21701/24009 with 1 missing, elapsed time: 86.595
# Imputing row 21801/24009 with 1 missing, elapsed time: 86.605
# Imputing row 21901/24009 with 0 missing, elapsed time: 86.617
# Imputing row 22001/24009 with 0 missing, elapsed time: 86.627
# Imputing row 22101/24009 with 0 missing, elapsed time: 86.636
# Imputing row 22201/24009 with 1 missing, elapsed time: 86.645
# Imputing row 22301/24009 with 1 missing, elapsed time: 86.653
# Imputing row 22401/24009 with 1 missing, elapsed time: 86.662
# Imputing row 22501/24009 with 1 missing, elapsed time: 86.672
# Imputing row 22601/24009 with 0 missing, elapsed time: 86.682
# Imputing row 22701/24009 with 0 missing, elapsed time: 86.693
# Imputing row 22801/24009 with 0 missing, elapsed time: 86.703
# Imputing row 22901/24009 with 0 missing, elapsed time: 86.713
# Imputing row 23001/24009 with 0 missing, elapsed time: 86.721
# Imputing row 23101/24009 with 0 missing, elapsed time: 86.730
# Imputing row 23201/24009 with 1 missing, elapsed time: 86.740
# Imputing row 23301/24009 with 1 missing, elapsed time: 86.750
# Imputing row 23401/24009 with 0 missing, elapsed time: 86.758
# Imputing row 23501/24009 with 1 missing, elapsed time: 86.768
# Imputing row 23601/24009 with 1 missing, elapsed time: 86.776
# Imputing row 23701/24009 with 0 missing, elapsed time: 86.785
# Imputing row 23801/24009 with 1 missing, elapsed time: 86.797
# Imputing row 23901/24009 with 0 missing, elapsed time: 86.806
# Imputing row 24001/24009 with 1 missing, elapsed time: 86.816

# %% [markdown]
# #### Comparison of the samples generated by MICE method and KNN

# %%
pd.DataFrame(final_matrix_knn, columns = [x for x in list(column_names)]).PosterAge.hist()

# %%
pd.DataFrame(final_matrix_mice, columns = [x for x in list(column_names)]).PosterAge.hist()

# %%
pd_final_mice = pd.DataFrame(final_matrix_knn, columns = [x for x in list(column_names)])
pd_final_knn = pd.DataFrame(final_matrix_knn, columns = [x for x in list(column_names)])

# %%
pd_final_mice.describe()
# Out:
#            TagCount   TitleLength  PosterReputation     PosterAge  \
# count  24009.000000  24009.000000      24009.000000  24009.000000
# mean       2.058895     59.923320      15403.269899     34.181328
# std        0.992615     22.637822      38484.197158      9.791207
# min        1.000000     15.000000          1.000000     13.999999
# 25%        1.000000     43.000000        109.000000     27.215078
# 50%        2.000000     57.000000        803.000000     32.792745
# 75%        3.000000     73.000000       8117.000000     39.000000
# max        5.000000    168.000000     198942.000000     96.000000
#
#           FinalTime  CensoringStatus
# count  2.400900e+04     24009.000000
# mean   2.195890e+07         0.538715
# std    3.553241e+07         0.498509
# min    4.096000e+03         0.000000
# 25%    8.192000e+03         0.000000
# 50%    2.088960e+05         1.000000
# 75%    3.276390e+07         1.000000
# max    1.624433e+08         1.000000

# %%
pd_final_knn.describe()
# Out:
#            TagCount   TitleLength  PosterReputation     PosterAge  \
# count  24009.000000  24009.000000      24009.000000  24009.000000
# mean       2.058895     59.923320      15403.269899     34.181328
# std        0.992615     22.637822      38484.197158      9.791207
# min        1.000000     15.000000          1.000000     13.999999
# 25%        1.000000     43.000000        109.000000     27.215078
# 50%        2.000000     57.000000        803.000000     32.792745
# 75%        3.000000     73.000000       8117.000000     39.000000
# max        5.000000    168.000000     198942.000000     96.000000
#
#           FinalTime  CensoringStatus
# count  2.400900e+04     24009.000000
# mean   2.195890e+07         0.538715
# std    3.553241e+07         0.498509
# min    4.096000e+03         0.000000
# 25%    8.192000e+03         0.000000
# 50%    2.088960e+05         1.000000
# 75%    3.276390e+07         1.000000
# max    1.624433e+08         1.000000

# %% [markdown]
# Choosing knn adjust as it is more similar to the previous data

# %%
final_knn_df = sqlContext.createDataFrame(pd_final_knn)

# %% [markdown]
# # Exploratory analysis

# %%
fig_size = []
fig_size.append(15)
fig_size.append(15)
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# ## Correlation and covariance matrixes

# %% [markdown]
# ### Original DF

# %%
final_knn_df.toPandas().describe()
# Out:
#            TagCount   TitleLength  PosterReputation     PosterAge  \
# count  24009.000000  24009.000000      24009.000000  24009.000000
# mean       2.058895     59.923320      15403.269899     34.181328
# std        0.992615     22.637822      38484.197158      9.791207
# min        1.000000     15.000000          1.000000     13.999999
# 25%        1.000000     43.000000        109.000000     27.215078
# 50%        2.000000     57.000000        803.000000     32.792745
# 75%        3.000000     73.000000       8117.000000     39.000000
# max        5.000000    168.000000     198942.000000     96.000000
#
#           FinalTime  CensoringStatus
# count  2.400900e+04     24009.000000
# mean   2.195890e+07         0.538715
# std    3.553241e+07         0.498509
# min    4.096000e+03         0.000000
# 25%    8.192000e+03         0.000000
# 50%    2.088960e+05         1.000000
# 75%    3.276390e+07         1.000000
# max    1.624433e+08         1.000000

# %%
fig_size = []
fig_size.append(15)
fig_size.append(10)
plt.rcParams["figure.figsize"] = fig_size
final_knn_df.toPandas().plot(kind='density', subplots=True, layout=(3,3), sharex=False)
plt.savefig('/Users/Mat/github/survival_analysis/paper/images/variables_density_distribution.png',\
            format='png', dpi=300)

# %%
final_knn_df.drop("CensoringStatus").toPandas().corr()
# Out:
#                   TagCount  TitleLength  PosterReputation  PosterAge  \
# TagCount          1.000000     0.060511         -0.015749   0.007831
# TitleLength       0.060511     1.000000         -0.019001   0.053733
# PosterReputation -0.015749    -0.019001          1.000000   0.233575
# PosterAge         0.007831     0.053733          0.233575   1.000000
# FinalTime        -0.018741     0.071873          0.010410   0.046981
#
#                   FinalTime
# TagCount          -0.018741
# TitleLength        0.071873
# PosterReputation   0.010410
# PosterAge          0.046981
# FinalTime          1.000000

# %% [markdown]
# ### Transformed DF

# %%
log_scale_udf = udf(lambda x: float(np.log10(x)), stypes.FloatType())

# %%
final_knn_df_log = final_knn_df.\
withColumn("logFinalTime", log_scale_udf(final_knn_df.FinalTime)).\
withColumn("logPosterReputation", log_scale_udf(final_knn_df.PosterReputation)).\
select("TagCount", "TitleLength","logPosterReputation", "PosterAge", "logFinalTime", "CensoringStatus")

# %%
final_knn_df_log.toPandas().describe()
# Out:
#            TagCount   TitleLength  logPosterReputation     PosterAge  \
# count  24009.000000  24009.000000         24009.000000  24009.000000
# mean       2.058895     59.923320             2.930076     34.181328
# std        0.992615     22.637822             1.256656      9.791207
# min        1.000000     15.000000             0.000000     13.999999
# 25%        1.000000     43.000000             2.037426     27.215078
# 50%        2.000000     57.000000             2.904716     32.792745
# 75%        3.000000     73.000000             3.909395     39.000000
# max        5.000000    168.000000             5.298727     96.000000
#
#        logFinalTime  CensoringStatus
# count  24009.000000     24009.000000
# mean       5.701602         0.538715
# std        1.725381         0.498509
# min        3.612360         0.000000
# 25%        3.913390         0.000000
# 50%        5.319930         1.000000
# 75%        7.515396         1.000000
# max        8.210702         1.000000

# %%
fig_size = []
fig_size.append(15)
fig_size.append(10)
plt.rcParams["figure.figsize"] = fig_size
final_knn_df_log.\
drop("FinalTime","PosterReputation").\
toPandas().plot(kind='density', subplots=True, layout=(3,3), sharex=False)
plt.savefig('/Users/Mat/github/survival_analysis/paper/images/variables_density_distribution_log.png',\
            format='png', dpi=300)

# %%
final_knn_df_log.drop("CensoringStatus").toPandas().corr()
# Out:
#                      TagCount  TitleLength  logPosterReputation  PosterAge  \
# TagCount             1.000000     0.060511             0.007121   0.007831
# TitleLength          0.060511     1.000000            -0.109614   0.053733
# logPosterReputation  0.007121    -0.109614             1.000000   0.191537
# PosterAge            0.007831     0.053733             0.191537   1.000000
# logFinalTime        -0.006862     0.093518            -0.226488   0.009140
#
#                      logFinalTime
# TagCount                -0.006862
# TitleLength              0.093518
# logPosterReputation     -0.226488
# PosterAge                0.009140
# logFinalTime             1.000000

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(final_knn_df_log.
drop("CensoringStatus").toPandas(), diagonal='kde')
plt.savefig('/Users/Mat/github/survival_analysis/paper/images/correlation_density_log.png', format='png', dpi=200)

# %% [markdown]
# ## Data output to file

# %%
final_knn_df.\
withColumn("logFinalTime", log_scale_udf(final_knn_df.FinalTime)).\
withColumn("logPosterReputation", log_scale_udf(final_knn_df.PosterReputation)).\
select("FinalTime", "CensoringStatus", "TagCount", "TitleLength","logPosterReputation", "PosterAge").\
write.csv("/Users/Mat/Desktop/final_df_fill_transformed")
